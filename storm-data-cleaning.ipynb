# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import warnings

# Hiding warnings
warnings.filterwarnings('ignore')

# File to Load
data_to_load = Path('Resources/raw_data/storm_raw_data.csv')

# Read Data File and store into Pandas DataFrames
raw_data = pd.read_csv(data_to_load)

raw_data.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202401         29        1000         202401       30       900
# 1           202401         13         330         202401       13       540
# 2           202401         13         330         202401       13       540
# 3           202401         13         330         202401       13       540
# 4           202402         28         700         202402       28       845
#
#    EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  ...  END_RANGE  \
# 0      188640   1160769         ALASKA           2  ...       10.0
# 1      188650   1159956  LAKE SUPERIOR          92  ...        2.0
# 2      188650   1159913  LAKE SUPERIOR          92  ...        2.0
# 3      188650   1159953  LAKE SUPERIOR          92  ...        7.0
# 4      189314   1165191  LAKE SUPERIOR          92  ...        0.0
#
#   END_AZIMUTH          END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT   END_LON  \
# 0          NW               DOUGLAS   58.3620  -134.5824  58.3625 -134.5798
# 1           E         COPPER HARBOR   47.4703   -87.8403  47.4703  -87.8403
# 2           E         COPPER HARBOR   47.4688   -87.8665  47.4688  -87.8665
# 3           W  MANITOU ISLAND LIGHT   47.4298   -87.7144  47.4298  -87.7144
# 4           N   STANNARD ROCK LIGHT   47.1800   -87.2300  47.1800  -87.2300
#
#                                    EPISODE_NARRATIVE  \
# 0  A strong storm force low pressure system over ...
# 1  A powerful storm system moving through the Upp...
# 2  A powerful storm system moving through the Upp...
# 3  A powerful storm system moving through the Upp...
# 4  North to northwest storm force winds between 5...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0  Rain and rising freezing levels moved over the...         CSV
# 1  The Copper Harbor ASOS measured storm force no...         CSV
# 2  The Copper Harbor ASOS measured storm force no...         CSV
# 3  The Copper Harbor ASOS measured storm force no...         CSV
# 4  The Stannard Rock C-MAN station measured storm...         CSV
#
# [5 rows x 51 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11945 entries, 0 to 11944
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     11945 non-null  int64
#  1   BEGIN_DAY           11945 non-null  int64
#  2   BEGIN_TIME          11945 non-null  int64
#  3   END_YEARMONTH       11945 non-null  int64
#  4   END_DAY             11945 non-null  int64
#  5   END_TIME            11945 non-null  int64
#  6   EPISODE_ID          11945 non-null  int64
#  7   EVENT_ID            11945 non-null  int64
#  8   STATE               11945 non-null  object
#  9   STATE_FIPS          11945 non-null  int64
#  10  YEAR                11945 non-null  int64
#  11  MONTH_NAME          11945 non-null  object
#  12  EVENT_TYPE          11945 non-null  object
#  13  CZ_TYPE             11945 non-null  object
#  14  CZ_FIPS             11945 non-null  int64
#  15  CZ_NAME             11945 non-null  object
#  16  WFO                 11945 non-null  object
#  17  BEGIN_DATE_TIME     11945 non-null  object
#  18  CZ_TIMEZONE         11945 non-null  object
#  19  END_DATE_TIME       11945 non-null  object
#  20  INJURIES_DIRECT     11945 non-null  int64
#  21  INJURIES_INDIRECT   11945 non-null  int64
#  22  DEATHS_DIRECT       11945 non-null  int64
#  23  DEATHS_INDIRECT     11945 non-null  int64
#  24  DAMAGE_PROPERTY     9560 non-null   object
#  25  DAMAGE_CROPS        9616 non-null   object
#  26  SOURCE              11945 non-null  object
#  27  MAGNITUDE           3152 non-null   float64
#  28  MAGNITUDE_TYPE      2745 non-null   object
#  29  FLOOD_CAUSE         946 non-null    object
#  30  CATEGORY            0 non-null      float64
#  31  TOR_F_SCALE         104 non-null    object
#  32  TOR_LENGTH          104 non-null    float64
#  33  TOR_WIDTH           104 non-null    float64
#  34  TOR_OTHER_WFO       16 non-null     object
#  35  TOR_OTHER_CZ_STATE  16 non-null     object
#  36  TOR_OTHER_CZ_FIPS   16 non-null     float64
#  37  TOR_OTHER_CZ_NAME   16 non-null     object
#  38  BEGIN_RANGE         2673 non-null   float64
#  39  BEGIN_AZIMUTH       2673 non-null   object
#  40  BEGIN_LOCATION      2673 non-null   object
#  41  END_RANGE           2673 non-null   float64
#  42  END_AZIMUTH         2673 non-null   object
#  43  END_LOCATION        2673 non-null   object
#  44  BEGIN_LAT           2673 non-null   float64
#  45  BEGIN_LON           2673 non-null   float64
#  46  END_LAT             2673 non-null   float64
#  47  END_LON             2673 non-null   float64
#  48  EPISODE_NARRATIVE   11945 non-null  object
#  49  EVENT_NARRATIVE     9698 non-null   object
#  50  DATA_SOURCE         11945 non-null  object
# dtypes: float64(11), int64(15), object(25)
# memory usage: 4.6+ MB

# %%
# Removing unnecessary columns
columns_to_keep = ["YEAR", "MONTH_NAME","BEGIN_DAY", "BEGIN_DATE_TIME", "DAMAGE_PROPERTY", "EVENT_TYPE", "STATE", "TOR_F_SCALE", "BEGIN_LOCATION", "BEGIN_LAT", "BEGIN_LON", "EVENT_NARRATIVE"]

filtered_data = raw_data[columns_to_keep]

# Removing rows with missing coordinates and property damage is $0
filtered_data = filtered_data.dropna(subset=["BEGIN_LAT", "DAMAGE_PROPERTY"])


# Ensure "DAMAGE_PROPERTY" is treated as string and strip any whitespace
filtered_data["DAMAGE_PROPERTY"] = filtered_data["DAMAGE_PROPERTY"].astype(str).str.strip()


filtered_data = filtered_data.dropna(subset=["BEGIN_LAT"])
filtered_data = filtered_data[~filtered_data["DAMAGE_PROPERTY"].isin(["0.00K", "0.0"])]

filtered_data.head()
# Out:
#     YEAR MONTH_NAME  BEGIN_DAY     BEGIN_DATE_TIME DAMAGE_PROPERTY  \
# 16  2024    January         16  16-JAN-24 09:42:00         100.00K
# 17  2024   February         26  26-FEB-24 15:30:00           7.50K
# 23  2024    January         10  10-JAN-24 09:00:00         200.00K
# 24  2024    January         13  13-JAN-24 11:00:00         200.00K
# 25  2024    January         10  10-JAN-24 09:00:00         200.00K
#
#            EVENT_TYPE    STATE TOR_F_SCALE     BEGIN_LOCATION  BEGIN_LAT  \
# 16              Flood  MONTANA         NaN   (DLN)DILLON ARPT    45.2500
# 17  Thunderstorm Wind   OREGON         NaN             LACOMB    44.6201
# 23        Flash Flood    MAINE         NaN           PORTLAND    43.6712
# 24        Flash Flood    MAINE         NaN           PORTLAND    43.6710
# 25        Flash Flood    MAINE         NaN  OLD ORCHARD BEACH    43.5576
#
#     BEGIN_LON                                    EVENT_NARRATIVE
# 16  -112.6000  Reported ice jam along the Beaverhead River no...
# 17  -122.7533  Property owner reported damage to 6 trees, alo...
# 23   -70.2589  Heavy rain and snowmelt impacted Cumberland Co...
# 24   -70.2586  A coastal front was established along coastal ...
# 25   -70.3884  Heavy rain and snowmelt impacted Coastal York ...

# %%
# Converting Property Damage to USD, removing decimal, converting to integer

def convert_damage(value):
    if isinstance(value, str):
        if 'K' in value.upper():
            return int(float(value[:-1]) * 1000)
        elif 'M' in value.upper():
            return int(float(value[:-1]) * 1000000)
        else:
            return int(float(value))
    return int(value)

# Apply the conversion function to the DAMAGE_PROPERTY column
filtered_data['DAMAGE_PROPERTY'] = filtered_data['DAMAGE_PROPERTY'].apply(convert_damage)

# Renaming "Flash Flood" to "Flood"
filtered_data['EVENT_TYPE'] = filtered_data['EVENT_TYPE'].replace('Flash Flood', 'Flood')

filtered_data.head()
# Out:
#     YEAR MONTH_NAME  BEGIN_DAY     BEGIN_DATE_TIME  DAMAGE_PROPERTY  \
# 16  2024    January         16  16-JAN-24 09:42:00           100000
# 17  2024   February         26  26-FEB-24 15:30:00             7500
# 23  2024    January         10  10-JAN-24 09:00:00           200000
# 24  2024    January         13  13-JAN-24 11:00:00           200000
# 25  2024    January         10  10-JAN-24 09:00:00           200000
#
#            EVENT_TYPE    STATE TOR_F_SCALE     BEGIN_LOCATION  BEGIN_LAT  \
# 16              Flood  MONTANA         NaN   (DLN)DILLON ARPT    45.2500
# 17  Thunderstorm Wind   OREGON         NaN             LACOMB    44.6201
# 23              Flood    MAINE         NaN           PORTLAND    43.6712
# 24              Flood    MAINE         NaN           PORTLAND    43.6710
# 25              Flood    MAINE         NaN  OLD ORCHARD BEACH    43.5576
#
#     BEGIN_LON                                    EVENT_NARRATIVE
# 16  -112.6000  Reported ice jam along the Beaverhead River no...
# 17  -122.7533  Property owner reported damage to 6 trees, alo...
# 23   -70.2589  Heavy rain and snowmelt impacted Cumberland Co...
# 24   -70.2586  A coastal front was established along coastal ...
# 25   -70.3884  Heavy rain and snowmelt impacted Coastal York ...

# %%
# Checking info
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 16 to 2672
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YEAR             724 non-null    int64
#  1   MONTH_NAME       724 non-null    object
#  2   BEGIN_DAY        724 non-null    int64
#  3   BEGIN_DATE_TIME  724 non-null    object
#  4   DAMAGE_PROPERTY  724 non-null    int64
#  5   EVENT_TYPE       724 non-null    object
#  6   STATE            724 non-null    object
#  7   TOR_F_SCALE      45 non-null     object
#  8   BEGIN_LOCATION   724 non-null    object
#  9   BEGIN_LAT        724 non-null    float64
#  10  BEGIN_LON        724 non-null    float64
#  11  EVENT_NARRATIVE  724 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 73.5+ KB

# %%
# Converting BEGIN_DATE_TIME to datetime
filtered_data["BEGIN_DATE_TIME"] = pd.to_datetime(filtered_data["BEGIN_DATE_TIME"], format="%d-%b-%y %H:%M:%S")

# Creating TIME_OF_DAY column
filtered_data["TIME_OF_DAY"] = filtered_data["BEGIN_DATE_TIME"].dt.time


# Reordering columns
columns_order = ["YEAR", "MONTH_NAME","BEGIN_DAY","BEGIN_DATE_TIME","TIME_OF_DAY", "DAMAGE_PROPERTY", "EVENT_TYPE", "STATE", "TOR_F_SCALE", "BEGIN_LOCATION", "BEGIN_LAT", "BEGIN_LON", "EVENT_NARRATIVE"]
filtered_data = filtered_data[columns_order]

filtered_data.head()
# Out:
#     YEAR MONTH_NAME  BEGIN_DAY     BEGIN_DATE_TIME TIME_OF_DAY  \
# 16  2024    January         16 2024-01-16 09:42:00    09:42:00
# 17  2024   February         26 2024-02-26 15:30:00    15:30:00
# 23  2024    January         10 2024-01-10 09:00:00    09:00:00
# 24  2024    January         13 2024-01-13 11:00:00    11:00:00
# 25  2024    January         10 2024-01-10 09:00:00    09:00:00
#
#     DAMAGE_PROPERTY         EVENT_TYPE    STATE TOR_F_SCALE  \
# 16           100000              Flood  MONTANA         NaN
# 17             7500  Thunderstorm Wind   OREGON         NaN
# 23           200000              Flood    MAINE         NaN
# 24           200000              Flood    MAINE         NaN
# 25           200000              Flood    MAINE         NaN
#
#        BEGIN_LOCATION  BEGIN_LAT  BEGIN_LON  \
# 16   (DLN)DILLON ARPT    45.2500  -112.6000
# 17             LACOMB    44.6201  -122.7533
# 23           PORTLAND    43.6712   -70.2589
# 24           PORTLAND    43.6710   -70.2586
# 25  OLD ORCHARD BEACH    43.5576   -70.3884
#
#                                       EVENT_NARRATIVE
# 16  Reported ice jam along the Beaverhead River no...
# 17  Property owner reported damage to 6 trees, alo...
# 23  Heavy rain and snowmelt impacted Cumberland Co...
# 24  A coastal front was established along coastal ...
# 25  Heavy rain and snowmelt impacted Coastal York ...

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 16 to 2672
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YEAR             724 non-null    int64
#  1   MONTH_NAME       724 non-null    object
#  2   BEGIN_DAY        724 non-null    int64
#  3   BEGIN_DATE_TIME  724 non-null    datetime64[ns]
#  4   TIME_OF_DAY      724 non-null    object
#  5   DAMAGE_PROPERTY  724 non-null    int64
#  6   EVENT_TYPE       724 non-null    object
#  7   STATE            724 non-null    object
#  8   TOR_F_SCALE      45 non-null     object
#  9   BEGIN_LOCATION   724 non-null    object
#  10  BEGIN_LAT        724 non-null    float64
#  11  BEGIN_LON        724 non-null    float64
#  12  EVENT_NARRATIVE  724 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(7)
# memory usage: 79.2+ KB

# %%
# Export out clean_data.csv

output_path = Path('Resources/clean_data.csv')
filtered_data.to_csv(output_path, index=False)
